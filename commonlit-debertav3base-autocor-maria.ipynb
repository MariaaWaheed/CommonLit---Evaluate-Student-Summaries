# %%
# !pip install "/kaggle/input/pyspellchecker/pyspellchecker-0.7.2-py3-none-any.whl" 
# !pip install "/kaggle/input/autocorrect/autocorrect-2.6.1.tar"
# Out:
# Processing /kaggle/input/pyspellchecker/pyspellchecker-0.7.2-py3-none-any.whl
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2
# Processing /kaggle/input/autocorrect/autocorrect-2.6.1.tar
# done
# Building wheels for collected packages: autocorrect
# done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622383 sha256=84c1c776407c0e7aaf4b6e1e27623f05bee088365c87461590040d4dbc21ef37
#   Stored in directory: /root/.cache/pip/wheels/db/69/42/0fb0421d2fe70d195a04665edc760cfe5fd341d7bb8d8e0aaa
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from typing import List
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import logging
import os
import shutil
import json
import transformers
from transformers import AutoModel, AutoTokenizer, AutoConfig, AutoModelForSequenceClassification
from transformers import DataCollatorWithPadding
from datasets import Dataset,load_dataset, load_from_disk
from transformers import TrainingArguments, Trainer
from datasets import load_metric, disable_progress_bar
from sklearn.metrics import mean_squared_error
import torch
from sklearn.model_selection import KFold, GroupKFold
from tqdm import tqdm

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
from collections import Counter
import spacy
import re 

from autocorrect import Speller
from spellchecker import SpellChecker
 
import xgboost as xgb  
import lightgbm as lgb

warnings.simplefilter("ignore")
logging.disable(logging.ERROR)
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
disable_progress_bar()
tqdm.pandas()

# %%
# !cp -r /kaggle/input/rouge-score/rouge_score-0.1.2 /kaggle/working/
# !pip install /kaggle/working/rouge_score-0.1.2/
# Out:
# Processing ./rouge_score-0.1.2
# done
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from rouge-score==0.1.2) (1.4.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from rouge-score==0.1.2) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rouge-score==0.1.2) (1.23.5)
# Requirement already satisfied: six>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from rouge-score==0.1.2) (1.16.0)
# Building wheels for collected packages: rouge-score
# done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=7d0ed42b57dd23e705b0aba6ec45294af96f1e69216d8b3a379cb9602a65865e
#   Stored in directory: /root/.cache/pip/wheels/7f/65/32/aad94dce2cf8bf1ffd82591fee13cf08e3795101366d68f144
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from rouge_score import rouge_scorer
from itertools import combinations

def sentence_combinations(text):
    sentences = [s.strip() for s in text.split('.') if s.strip()]
    pairs = list(combinations(sentences, 2))
    return pairs

scorer_rogue = rouge_scorer.RougeScorer(['rouge1','rouge2','rougeL'], use_stemmer=True)

def get_rogue_f1s(text_t,text_p):
    scores = scorer_rogue.score(text_t,text_p)
    rg1 = scores['rouge1'][2]
    rg2 = scores['rouge2'][2]
    rgL = scores['rougeL'][2]
    return (rg1,rg2,rgL)
    

def get_avg_self_rogues(text):
    rg1s = []
    rg2s = []
    rgLs = []
    for sp in sentence_combinations(text):
        scores = scorer_rogue.score(sp[0],sp[1])
        rg1s.append(scores['rouge1'][2])
        rg2s.append(scores['rouge2'][2])
        rgLs.append(scores['rougeL'][2])
    return ( np.mean(rg1s),np.mean(rg2s),np.mean(rgLs) )


import nltk
from nltk.tokenize import sent_tokenize
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def self_bleu(text):
    sentences = sent_tokenize(text)
    scores = []
    smoothie = SmoothingFunction().method4
    for idx, candidate in enumerate(sentences):
        references = [s for i, s in enumerate(sentences) if i != idx]
        scores.append(sentence_bleu(references, candidate, smoothing_function=smoothie))
    average_score = sum(scores) / len(scores)
    return average_score

# %%
load_data = '/kaggle/input/commonlit-evaluate-student-summaries/'

# %%
prompts_train = pd.read_csv(load_data + 'prompts_train.csv') 
summaries_train = pd.read_csv(load_data + 'summaries_train.csv')

# %%
prompts_test = pd.read_csv('/kaggle/input/commonlit-evaluate-student-summaries/prompts_test.csv')
summaries_test = pd.read_csv('/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv')

# %%
def seed_everything(seed: int):
    import random, os
    import numpy as np
    import torch
    
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(seed=42)

# %%
class CFG:
    model_name="debertav3base"
    learning_rate=0.000015   #0.000015
    weight_decay=0.02        #0.02
    hidden_dropout_prob=0.007
    attention_probs_dropout_prob=0.007
    num_train_epochs=4 #4
    n_splits=4
    batch_size=12
    random_seed=42
    save_steps=100
    max_length=512

# %%
model_name="debertav3base"
from transformers import AutoTokenizer

# %%
class Preprocessor:
    def __init__(self, 
                model_name: str,
                ) -> None:
        self.tokenizer = AutoTokenizer.from_pretrained(f"/kaggle/input/{model_name}")
        self.twd = TreebankWordDetokenizer()
        self.STOP_WORDS = set(stopwords.words('english'))
        
        self.spacy_ner_model = spacy.load('en_core_web_sm',)
        self.speller = Speller(lang='en')
        self.spellchecker = SpellChecker() 
        
    def word_overlap_count(self, row):
        """ intersection(prompt_text, text) """        
        def check_is_stop_word(word):
            return word in self.STOP_WORDS
        
        prompt_words = row['prompt_tokens']
        summary_words = row['summary_tokens']
        if self.STOP_WORDS:
            prompt_words = list(filter(check_is_stop_word, prompt_words))
            summary_words = list(filter(check_is_stop_word, summary_words))
        return len(set(prompt_words).intersection(set(summary_words)))
            
    def ngrams(self, token, n):
        # Use the zip function to help us generate n-grams
        # Concatentate the tokens into ngrams and return
        ngrams = zip(*[token[i:] for i in range(n)])
        return [" ".join(ngram) for ngram in ngrams]

    def ngram_co_occurrence(self, row, n: int) -> int:
        # Tokenize the original text and summary into words
        original_tokens = row['prompt_tokens']
        summary_tokens = row['summary_tokens']

        # Generate n-grams for the original text and summary
        original_ngrams = set(self.ngrams(original_tokens, n))
        summary_ngrams = set(self.ngrams(summary_tokens, n))

        # Calculate the number of common n-grams
        common_ngrams = original_ngrams.intersection(summary_ngrams)
        return len(common_ngrams)
    
    def ner_overlap_count(self, row, mode:str):
        model = self.spacy_ner_model
        def clean_ners(ner_list):
            return set([(ner[0].lower(), ner[1]) for ner in ner_list])
        prompt = model(row['prompt_text'])
        summary = model(row['text'])

        if "spacy" in str(model):
            prompt_ner = set([(token.text, token.label_) for token in prompt.ents])
            summary_ner = set([(token.text, token.label_) for token in summary.ents])
        elif "stanza" in str(model):
            prompt_ner = set([(token.text, token.type) for token in prompt.ents])
            summary_ner = set([(token.text, token.type) for token in summary.ents])
        else:
            raise Exception("Model not supported")

        prompt_ner = clean_ners(prompt_ner)
        summary_ner = clean_ners(summary_ner)

        intersecting_ners = prompt_ner.intersection(summary_ner)
        
        ner_dict = dict(Counter([ner[1] for ner in intersecting_ners]))
        
        if mode == "train":
            return ner_dict
        elif mode == "test":
            return {key: ner_dict.get(key) for key in self.ner_keys}

    
    def quotes_count(self, row):
        summary = row['text']
        text = row['prompt_text']
        quotes_from_summary = re.findall(r'"([^"]*)"', summary)
        if len(quotes_from_summary)>0:
            return [quote in text for quote in quotes_from_summary].count(True)
        else:
            return 0

    def spelling(self, text):
        
        wordlist=text.split()
        amount_miss = len(list(self.spellchecker.unknown(wordlist)))

        return amount_miss
    
    def add_spelling_dictionary(self, tokens: List[str]) -> List[str]:
        """dictionary update for pyspell checker and autocorrect"""
        self.spellchecker.word_frequency.load_words(tokens)
        self.speller.nlp_data.update({token:1000 for token in tokens})
    
    def run(self, 
            prompts: pd.DataFrame,
            summaries:pd.DataFrame,
            mode:str
        ) -> pd.DataFrame:
        
        # before merge preprocess
        prompts["prompt_length"] = prompts["prompt_text"].apply(
            lambda x: len(word_tokenize(x))
        )
        prompts["prompt_tokens"] = prompts["prompt_text"].apply(
            lambda x: word_tokenize(x)
        )

        summaries["summary_length"] = summaries["text"].apply(
            lambda x: len(word_tokenize(x))
        )
        summaries["summary_tokens"] = summaries["text"].apply(
            lambda x: word_tokenize(x)
        )
        
        # Add prompt tokens into spelling checker dictionary
        prompts["prompt_tokens"].apply(
            lambda x: self.add_spelling_dictionary(x)
        )
        
#         from IPython.core.debugger import Pdb; Pdb().set_trace()
        # fix misspelling
        summaries["fixed_summary_text"] = summaries["text"].progress_apply(
            lambda x: self.speller(x)
        )
        
        # count misspelling
        summaries["splling_err_num"] = summaries["text"].progress_apply(self.spelling)
        
        # merge prompts and summaries
        input_df = summaries.merge(prompts, how="left", on="prompt_id")

        # after merge preprocess
        # input_df['length_ratio'] = input_df['summary_length'] / input_df['prompt_length']
        
        input_df['word_overlap_count'] = input_df.progress_apply(self.word_overlap_count, axis=1)
        input_df['bigram_overlap_count'] = input_df.progress_apply(
            self.ngram_co_occurrence,args=(2,), axis=1 
        )
        input_df['bigram_overlap_ratio'] = input_df['bigram_overlap_count'] / (input_df['summary_length'] - 1)
        
        input_df['trigram_overlap_count'] = input_df.progress_apply(
            self.ngram_co_occurrence, args=(3,), axis=1
        )
        input_df['trigram_overlap_ratio'] = input_df['trigram_overlap_count'] / (input_df['summary_length'] - 2)
        
        input_df['quotes_count'] = input_df.progress_apply(self.quotes_count, axis=1)
        
        return input_df.drop(columns=["summary_tokens", "prompt_tokens"])
    
preprocessor = Preprocessor(model_name=CFG.model_name)

# %%
train = preprocessor.run(prompts_train, summaries_train, mode="train")
test = preprocessor.run(prompts_test, summaries_test, mode="test")

train.head()
# Out:
# 100%|██████████| 7165/7165 [06:43<00:00, 17.78it/s]
# 100%|██████████| 7165/7165 [00:01<00:00, 6527.00it/s]
# 100%|██████████| 7165/7165 [00:00<00:00, 9589.17it/s]
# 100%|██████████| 7165/7165 [00:01<00:00, 5094.12it/s]
# 100%|██████████| 7165/7165 [00:01<00:00, 4526.85it/s]
# 100%|██████████| 7165/7165 [00:00<00:00, 86826.42it/s]
# 100%|██████████| 4/4 [00:00<00:00, 4123.18it/s]
# 100%|██████████| 4/4 [00:00<00:00, 6396.19it/s]
# 100%|██████████| 4/4 [00:00<00:00, 2347.78it/s]
# 100%|██████████| 4/4 [00:00<00:00, 3451.39it/s]
# 100%|██████████| 4/4 [00:00<00:00, 3088.59it/s]
# 100%|██████████| 4/4 [00:00<00:00, 2953.74it/s]
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
# 3  005ab0199905    3b9047  The highest class was Pharaohs these people we...
# 4  0070c9e7af47    814d6b  The Third Wave developed  rapidly because the ...
#
#     content   wording  summary_length  \
# 0  0.205683  0.380538              64
# 1 -0.548304  0.506755              54
# 2  3.128928  4.231226             269
# 3 -0.210614 -0.471415              28
# 4  3.272894  3.219757             232
#
#                                   fixed_summary_text  splling_err_num  \
# 0  The third wave was an experimental see how peo...                5
# 1  They would rub it up with soda to make the sme...                2
# 2  In Egypt, there were many occupations and soci...               32
# 3  The highest class was Pharaohs these people we...                5
# 4  The Third Wave developed  rapidly because the ...               29
#
#                                      prompt_question  \
# 0  Summarize how the Third Wave developed over su...
# 1  Summarize the various ways the factory would u...
# 2  In complete sentences, summarize the structure...
# 3  In complete sentences, summarize the structure...
# 4  Summarize how the Third Wave developed over su...
#
#                 prompt_title  \
# 0             The Third Wave
# 1    Excerpt from The Jungle
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4             The Third Wave
#
#                                          prompt_text  prompt_length  \
# 0  Background \r\nThe Third Wave experiment took ...            660
# 1  With one member trimming beef in a cannery, an...           1076
# 2  Egyptian society was structured like a pyramid...            625
# 3  Egyptian society was structured like a pyramid...            625
# 4  Background \r\nThe Third Wave experiment took ...            660
#
#    word_overlap_count  bigram_overlap_count  bigram_overlap_ratio  \
# 0                  14                     4              0.063492
# 1                  18                    22              0.415094
# 2                  22                    52              0.194030
# 3                   6                     6              0.222222
# 4                  23                    27              0.116883
#
#    trigram_overlap_count  trigram_overlap_ratio  quotes_count
# 0                      0               0.000000             0
# 1                     10               0.192308             0
# 2                     23               0.086142             2
# 3                      5               0.192308             0
# 4                      5               0.021739             4

# %%
gkf = GroupKFold(n_splits=CFG.n_splits)

for i, (_, val_index) in enumerate(gkf.split(train, groups=train["prompt_id"])):
    train.loc[val_index, "fold"] = i

train.head()
# Out:
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
# 3  005ab0199905    3b9047  The highest class was Pharaohs these people we...
# 4  0070c9e7af47    814d6b  The Third Wave developed  rapidly because the ...
#
#     content   wording  summary_length  \
# 0  0.205683  0.380538              64
# 1 -0.548304  0.506755              54
# 2  3.128928  4.231226             269
# 3 -0.210614 -0.471415              28
# 4  3.272894  3.219757             232
#
#                                   fixed_summary_text  splling_err_num  \
# 0  The third wave was an experimental see how peo...                5
# 1  They would rub it up with soda to make the sme...                2
# 2  In Egypt, there were many occupations and soci...               32
# 3  The highest class was Pharaohs these people we...                5
# 4  The Third Wave developed  rapidly because the ...               29
#
#                                      prompt_question  \
# 0  Summarize how the Third Wave developed over su...
# 1  Summarize the various ways the factory would u...
# 2  In complete sentences, summarize the structure...
# 3  In complete sentences, summarize the structure...
# 4  Summarize how the Third Wave developed over su...
#
#                 prompt_title  \
# 0             The Third Wave
# 1    Excerpt from The Jungle
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4             The Third Wave
#
#                                          prompt_text  prompt_length  \
# 0  Background \r\nThe Third Wave experiment took ...            660
# 1  With one member trimming beef in a cannery, an...           1076
# 2  Egyptian society was structured like a pyramid...            625
# 3  Egyptian society was structured like a pyramid...            625
# 4  Background \r\nThe Third Wave experiment took ...            660
#
#    word_overlap_count  bigram_overlap_count  bigram_overlap_ratio  \
# 0                  14                     4              0.063492
# 1                  18                    22              0.415094
# 2                  22                    52              0.194030
# 3                   6                     6              0.222222
# 4                  23                    27              0.116883
#
#    trigram_overlap_count  trigram_overlap_ratio  quotes_count  fold
# 0                      0               0.000000             0   3.0
# 1                     10               0.192308             0   2.0
# 2                     23               0.086142             2   1.0
# 3                      5               0.192308             0   1.0
# 4                      5               0.021739             4   3.0

# %% [markdown]
# # Model function

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    rmse = mean_squared_error(labels, predictions, squared=False)
    return {"rmse": rmse}

def compute_mcrmse(eval_pred):
    """
    Calculates mean columnwise root mean squared error
    https://www.kaggle.com/competitions/commonlit-evaluate-student-summaries/overview/evaluation
    """
    preds, labels = eval_pred

    col_rmse = np.sqrt(np.mean((preds - labels) ** 2, axis=0))
    mcrmse = np.mean(col_rmse)

    return {
        "content_rmse": col_rmse[0],
        "wording_rmse": col_rmse[1],
        "mcrmse": mcrmse,
    }

def compt_score(content_true, content_pred, wording_true, wording_pred):
    content_score = mean_squared_error(content_true, content_pred)**(1/2)
    wording_score = mean_squared_error(wording_true, wording_pred)**(1/2)
    
    return (content_score + wording_score)/2

# %% [markdown]
# # Deberta Regressor

# %%
class ContentScoreRegressor:
    def __init__(self, 
                model_name: str,
                model_dir: str,
                target: str,
                hidden_dropout_prob: float,
                attention_probs_dropout_prob: float,
                max_length: int,
                ):
        self.inputs = ["prompt_text", "prompt_title", "prompt_question", "fixed_summary_text"]
        self.input_col = "input"
        
        self.text_cols = [self.input_col] 
        self.target = target
        self.target_cols = [target]

        self.model_name = model_name
        self.model_dir = model_dir
        self.max_length = max_length
        
        self.tokenizer = AutoTokenizer.from_pretrained(f"/kaggle/input/{model_name}")
        self.model_config = AutoConfig.from_pretrained(f"/kaggle/input/{model_name}")
        
        self.model_config.update({
            "hidden_dropout_prob": hidden_dropout_prob,
            "attention_probs_dropout_prob": attention_probs_dropout_prob,
            "num_labels": 1,
            "problem_type": "regression",
        })
        
        seed_everything(seed=42)

        self.data_collator = DataCollatorWithPadding(
            tokenizer=self.tokenizer
        )


    def tokenize_function(self, examples: pd.DataFrame):
        labels = [examples[self.target]]
        tokenized = self.tokenizer(examples[self.input_col],
                         padding=False,
                         truncation=True,
                         max_length=self.max_length)
        return {
            **tokenized,
            "labels": labels,
        }
    
    def tokenize_function_test(self, examples: pd.DataFrame):
        tokenized = self.tokenizer(examples[self.input_col],
                         padding=False,
                         truncation=True,
                         max_length=self.max_length)
        return tokenized
        
    def train(self, 
            fold: int,
            train_df: pd.DataFrame,
            valid_df: pd.DataFrame,
            batch_size: int,
            learning_rate: float,
            weight_decay: float,
            num_train_epochs: float,
            save_steps: int,
        ) -> None:
        """fine-tuning"""
        
        sep = self.tokenizer.sep_token
        train_df[self.input_col] = (
                    train_df["prompt_title"] + sep 
                    + train_df["prompt_question"] + sep 
                    + train_df["fixed_summary_text"]
                  )

        valid_df[self.input_col] = (
                    valid_df["prompt_title"] + sep 
                    + valid_df["prompt_question"] + sep 
                    + valid_df["fixed_summary_text"]
                  )
        
        train_df = train_df[[self.input_col] + self.target_cols]
        valid_df = valid_df[[self.input_col] + self.target_cols]
        
        model_content = AutoModelForSequenceClassification.from_pretrained(
            f"/kaggle/input/{self.model_name}", 
            config=self.model_config
        )

        train_dataset = Dataset.from_pandas(train_df, preserve_index=False) 
        val_dataset = Dataset.from_pandas(valid_df, preserve_index=False) 
    
        train_tokenized_datasets = train_dataset.map(self.tokenize_function, batched=False)
        val_tokenized_datasets = val_dataset.map(self.tokenize_function, batched=False)

        # eg. "bert/fold_0/"
        model_fold_dir = os.path.join(self.model_dir, str(fold)) 
        
        training_args = TrainingArguments(
            output_dir=model_fold_dir,
            load_best_model_at_end=True, # select best model
            learning_rate=learning_rate,
            per_device_train_batch_size=batch_size,
            per_device_eval_batch_size=8,
            num_train_epochs=num_train_epochs,
            weight_decay=weight_decay,
            report_to='none',
            greater_is_better=False,
            save_strategy="steps",
            evaluation_strategy="steps",
            eval_steps=save_steps,
            save_steps=save_steps,
            metric_for_best_model="rmse",
            save_total_limit=1
        )

        trainer = Trainer(
            model=model_content,
            args=training_args,
            train_dataset=train_tokenized_datasets,
            eval_dataset=val_tokenized_datasets,
            tokenizer=self.tokenizer,
            compute_metrics=compute_metrics,
            data_collator=self.data_collator
        )

        trainer.train()
        
        model_content.save_pretrained(self.model_dir)
        self.tokenizer.save_pretrained(self.model_dir)

        
    def predict(self, 
                test_df: pd.DataFrame,
                fold: int,
               ):
        """predict content score"""
        
        sep = self.tokenizer.sep_token
        in_text = (
                    test_df["prompt_title"] + sep 
                    + test_df["prompt_question"] + sep 
                    + test_df["fixed_summary_text"]
                  )
        test_df[self.input_col] = in_text

        test_ = test_df[[self.input_col]]
    
        test_dataset = Dataset.from_pandas(test_, preserve_index=False) 
        test_tokenized_dataset = test_dataset.map(self.tokenize_function_test, batched=False)

        model_content = AutoModelForSequenceClassification.from_pretrained(f"{self.model_dir}")
        model_content.eval()
        
        # e.g. "bert/fold_0/"
        model_fold_dir = os.path.join(self.model_dir, str(fold)) 

        test_args = TrainingArguments(
            output_dir=model_fold_dir,
            do_train = False,
            do_predict = True,
            per_device_eval_batch_size = 4,   
            dataloader_drop_last = False,
        )

        # init trainer
        infer_content = Trainer(
                      model = model_content, 
                      tokenizer=self.tokenizer,
                      data_collator=self.data_collator,
                      args = test_args)

        preds = infer_content.predict(test_tokenized_dataset)[0]

        return preds

# %%
def train_by_fold(
        train_df: pd.DataFrame,
        model_name: str,
        target:str,
        save_each_model: bool,
        n_splits: int,
        batch_size: int,
        learning_rate: int,
        hidden_dropout_prob: float,
        attention_probs_dropout_prob: float,
        weight_decay: float,
        num_train_epochs: int,
        save_steps: int,
        max_length:int
    ):

    # delete old model files
    if os.path.exists(model_name):
        shutil.rmtree(model_name)
    
    os.mkdir(model_name)
        
    for fold in range(CFG.n_splits):
        print(f"fold {fold}:")
        
        train_data = train_df[train_df["fold"] != fold]
        valid_data = train_df[train_df["fold"] == fold]
        
        if save_each_model == True:
            model_dir =  f"{target}/{model_name}/fold_{fold}"
        else: 
            model_dir =  f"{model_name}/fold_{fold}"

        csr = ContentScoreRegressor(
            model_name=model_name,
            target=target,
            model_dir = model_dir, 
            hidden_dropout_prob=hidden_dropout_prob,
            attention_probs_dropout_prob=attention_probs_dropout_prob,
            max_length=max_length,
           )
        
        csr.train(
            fold=fold,
            train_df=train_data,
            valid_df=valid_data, 
            batch_size=batch_size,
            learning_rate=learning_rate,
            weight_decay=weight_decay,
            num_train_epochs=num_train_epochs,
            save_steps=save_steps,
        )

def validate(
    train_df: pd.DataFrame,
    target:str,
    save_each_model: bool,
    model_name: str,
    hidden_dropout_prob: float,
    attention_probs_dropout_prob: float,
    max_length : int
    ) -> pd.DataFrame:
    """predict oof data"""
    for fold in range(CFG.n_splits):
        print(f"fold {fold}:")
        
        valid_data = train_df[train_df["fold"] == fold]
        
        if save_each_model == True:
            model_dir =  f"{target}/{model_name}/fold_{fold}"
        else: 
            model_dir =  f"{model_name}/fold_{fold}"
        
        csr = ContentScoreRegressor(
            model_name=model_name,
            target=target,
            model_dir = model_dir,
            hidden_dropout_prob=hidden_dropout_prob,
            attention_probs_dropout_prob=attention_probs_dropout_prob,
            max_length=max_length,
           )
        
        pred = csr.predict(
            test_df=valid_data, 
            fold=fold
        )
        
        train_df.loc[valid_data.index, f"{target}_pred"] = pred

    return train_df
    
def predict(
    test_df: pd.DataFrame,
    target:str,
    save_each_model: bool,
    model_name: str,
    hidden_dropout_prob: float,
    attention_probs_dropout_prob: float,
    max_length : int
    ):
    """predict using mean folds"""

    for fold in range(CFG.n_splits):
        print(f"fold {fold}:")
        
        if save_each_model == True:
            model_dir =  f"{target}/{model_name}/fold_{fold}"
        else: 
            model_dir =  f"{model_name}/fold_{fold}"

        csr = ContentScoreRegressor(
            model_name=model_name,
            target=target,
            model_dir = model_dir, 
            hidden_dropout_prob=hidden_dropout_prob,
            attention_probs_dropout_prob=attention_probs_dropout_prob,
            max_length=max_length,
           )
        
        pred = csr.predict(
            test_df=test_df, 
            fold=fold
        )
        
        test_df[f"{target}_pred_{fold}"] = pred
    
    test_df[f"{target}"] = test_df[[f"{target}_pred_{fold}" for fold in range(CFG.n_splits)]].mean(axis=1)

    return test_df

# %%
for target in ["content", "wording"]:
    train_by_fold(
        train,
        model_name=CFG.model_name,
        save_each_model=False,
        target=target,
        learning_rate=CFG.learning_rate,
        hidden_dropout_prob=CFG.hidden_dropout_prob,
        attention_probs_dropout_prob=CFG.attention_probs_dropout_prob,
        weight_decay=CFG.weight_decay,
        num_train_epochs=CFG.num_train_epochs,
        n_splits=CFG.n_splits,
        batch_size=CFG.batch_size,
        save_steps=CFG.save_steps,
        max_length=CFG.max_length
    )
    
    
    train = validate(
        train,
        target=target,
        save_each_model=False,
        model_name=CFG.model_name,
        hidden_dropout_prob=CFG.hidden_dropout_prob,
        attention_probs_dropout_prob=CFG.attention_probs_dropout_prob,
        max_length=CFG.max_length
    )

    rmse = mean_squared_error(train[target], train[f"{target}_pred"], squared=False)
    print(f"cv {target} rmse: {rmse}")

    test = predict(
        test,
        target=target,
        save_each_model=False,
        model_name=CFG.model_name,
        hidden_dropout_prob=CFG.hidden_dropout_prob,
        attention_probs_dropout_prob=CFG.attention_probs_dropout_prob,
        max_length=CFG.max_length
    )
# Out:
# fold 0:
#     <div>
#
#       <progress value='1704' max='1704' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1704/1704 20:19, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.231067</td>
#       <td>0.480695</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.258009</td>
#       <td>0.507946</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.239572</td>
#       <td>0.489461</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.494818</td>
#       <td>0.703433</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.273600</td>
#       <td>0.482845</td>
#       <td>0.694870</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.273600</td>
#       <td>0.193543</td>
#       <td>0.439935</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.273600</td>
#       <td>0.278226</td>
#       <td>0.527471</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.273600</td>
#       <td>0.343185</td>
#       <td>0.585820</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.273600</td>
#       <td>0.301421</td>
#       <td>0.549018</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.150400</td>
#       <td>0.356003</td>
#       <td>0.596660</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.150400</td>
#       <td>0.282434</td>
#       <td>0.531445</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.150400</td>
#       <td>0.303826</td>
#       <td>0.551204</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.150400</td>
#       <td>0.311199</td>
#       <td>0.557852</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.150400</td>
#       <td>0.287322</td>
#       <td>0.536024</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.102100</td>
#       <td>0.267604</td>
#       <td>0.517304</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.102100</td>
#       <td>0.272053</td>
#       <td>0.521587</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.102100</td>
#       <td>0.287557</td>
#       <td>0.536244</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 1:
#     <div>
#
#       <progress value='1720' max='1720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1720/1720 20:59, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.330423</td>
#       <td>0.574824</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.308816</td>
#       <td>0.555712</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.281600</td>
#       <td>0.530660</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.267217</td>
#       <td>0.516930</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.264700</td>
#       <td>0.285263</td>
#       <td>0.534100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.264700</td>
#       <td>0.275161</td>
#       <td>0.524558</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.264700</td>
#       <td>0.295855</td>
#       <td>0.543925</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.264700</td>
#       <td>0.282145</td>
#       <td>0.531173</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.264700</td>
#       <td>0.257316</td>
#       <td>0.507263</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.147700</td>
#       <td>0.277902</td>
#       <td>0.527164</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.147700</td>
#       <td>0.270074</td>
#       <td>0.519686</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.147700</td>
#       <td>0.257607</td>
#       <td>0.507550</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.147700</td>
#       <td>0.300678</td>
#       <td>0.548341</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.147700</td>
#       <td>0.281873</td>
#       <td>0.530917</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.101500</td>
#       <td>0.283059</td>
#       <td>0.532033</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.101500</td>
#       <td>0.263452</td>
#       <td>0.513276</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.101500</td>
#       <td>0.264787</td>
#       <td>0.514575</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 2:
#     <div>
#
#       <progress value='1724' max='1724' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1724/1724 20:54, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.270935</td>
#       <td>0.520514</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.231940</td>
#       <td>0.481601</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.229905</td>
#       <td>0.479484</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.264982</td>
#       <td>0.514764</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.266900</td>
#       <td>0.241694</td>
#       <td>0.491624</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.266900</td>
#       <td>0.236737</td>
#       <td>0.486556</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.266900</td>
#       <td>0.283323</td>
#       <td>0.532281</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.266900</td>
#       <td>0.239058</td>
#       <td>0.488936</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.266900</td>
#       <td>0.381927</td>
#       <td>0.618003</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.149000</td>
#       <td>0.449012</td>
#       <td>0.670083</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.149000</td>
#       <td>0.359383</td>
#       <td>0.599485</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.149000</td>
#       <td>0.305396</td>
#       <td>0.552626</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.149000</td>
#       <td>0.285346</td>
#       <td>0.534178</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.149000</td>
#       <td>0.351623</td>
#       <td>0.592978</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.104300</td>
#       <td>0.288965</td>
#       <td>0.537554</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.104300</td>
#       <td>0.362326</td>
#       <td>0.601935</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.104300</td>
#       <td>0.308246</td>
#       <td>0.555199</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 3:
#     <div>
#
#       <progress value='2024' max='2024' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2024/2024 21:02, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.413500</td>
#       <td>0.643040</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.644407</td>
#       <td>0.802749</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.368069</td>
#       <td>0.606687</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.303894</td>
#       <td>0.551266</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.249200</td>
#       <td>0.354082</td>
#       <td>0.595048</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.249200</td>
#       <td>0.619232</td>
#       <td>0.786913</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.249200</td>
#       <td>0.484761</td>
#       <td>0.696248</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.249200</td>
#       <td>0.332791</td>
#       <td>0.576880</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.249200</td>
#       <td>0.376372</td>
#       <td>0.613492</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.144300</td>
#       <td>0.460430</td>
#       <td>0.678550</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.144300</td>
#       <td>0.495459</td>
#       <td>0.703888</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.144300</td>
#       <td>0.376180</td>
#       <td>0.613335</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.144300</td>
#       <td>0.475042</td>
#       <td>0.689233</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.144300</td>
#       <td>0.486414</td>
#       <td>0.697434</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.104900</td>
#       <td>0.626858</td>
#       <td>0.791744</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.104900</td>
#       <td>0.585276</td>
#       <td>0.765034</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.104900</td>
#       <td>0.402882</td>
#       <td>0.634730</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.104900</td>
#       <td>0.528897</td>
#       <td>0.727253</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.104900</td>
#       <td>0.528794</td>
#       <td>0.727182</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.072200</td>
#       <td>0.502784</td>
#       <td>0.709073</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 0:
# fold 1:
# fold 2:
# fold 3:
# cv content rmse: 0.4884072888272623
# fold 0:
# fold 1:
# fold 2:
# fold 3:
# fold 0:
#     <div>
#
#       <progress value='1704' max='1704' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1704/1704 20:15, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.599047</td>
#       <td>0.773981</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.392314</td>
#       <td>0.626350</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.376464</td>
#       <td>0.613566</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.331142</td>
#       <td>0.575449</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.469300</td>
#       <td>0.335705</td>
#       <td>0.579400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.469300</td>
#       <td>0.336641</td>
#       <td>0.580208</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.469300</td>
#       <td>0.304208</td>
#       <td>0.551551</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.469300</td>
#       <td>0.321962</td>
#       <td>0.567417</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.469300</td>
#       <td>0.307394</td>
#       <td>0.554431</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.261500</td>
#       <td>0.305302</td>
#       <td>0.552541</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.261500</td>
#       <td>0.286213</td>
#       <td>0.534989</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.261500</td>
#       <td>0.301850</td>
#       <td>0.549409</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.261500</td>
#       <td>0.288777</td>
#       <td>0.537380</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.261500</td>
#       <td>0.305414</td>
#       <td>0.552642</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.171600</td>
#       <td>0.297331</td>
#       <td>0.545281</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.171600</td>
#       <td>0.299740</td>
#       <td>0.547485</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.171600</td>
#       <td>0.294932</td>
#       <td>0.543077</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 1:
#     <div>
#
#       <progress value='1720' max='1720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1720/1720 21:07, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.661426</td>
#       <td>0.813281</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.612108</td>
#       <td>0.782373</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.654053</td>
#       <td>0.808736</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.650458</td>
#       <td>0.806510</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.397500</td>
#       <td>0.728739</td>
#       <td>0.853662</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.397500</td>
#       <td>0.745287</td>
#       <td>0.863300</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.397500</td>
#       <td>0.845682</td>
#       <td>0.919610</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.397500</td>
#       <td>0.645473</td>
#       <td>0.803413</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.397500</td>
#       <td>0.745909</td>
#       <td>0.863660</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.231200</td>
#       <td>0.792565</td>
#       <td>0.890261</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.231200</td>
#       <td>0.586007</td>
#       <td>0.765511</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.231200</td>
#       <td>0.573717</td>
#       <td>0.757441</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.231200</td>
#       <td>0.677943</td>
#       <td>0.823373</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.231200</td>
#       <td>0.631725</td>
#       <td>0.794811</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.163700</td>
#       <td>0.609365</td>
#       <td>0.780618</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.163700</td>
#       <td>0.669953</td>
#       <td>0.818506</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.163700</td>
#       <td>0.628796</td>
#       <td>0.792967</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 2:
#     <div>
#
#       <progress value='1724' max='1724' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1724/1724 20:51, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.590249</td>
#       <td>0.768277</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.469994</td>
#       <td>0.685561</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.471390</td>
#       <td>0.686578</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.389535</td>
#       <td>0.624127</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.470300</td>
#       <td>0.391704</td>
#       <td>0.625863</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.470300</td>
#       <td>0.517236</td>
#       <td>0.719191</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.470300</td>
#       <td>0.346740</td>
#       <td>0.588846</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.470300</td>
#       <td>0.352928</td>
#       <td>0.594077</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.470300</td>
#       <td>0.316299</td>
#       <td>0.562405</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.290000</td>
#       <td>0.297514</td>
#       <td>0.545449</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.290000</td>
#       <td>0.329455</td>
#       <td>0.573982</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.290000</td>
#       <td>0.351783</td>
#       <td>0.593113</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.290000</td>
#       <td>0.306236</td>
#       <td>0.553386</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.290000</td>
#       <td>0.309402</td>
#       <td>0.556239</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.191400</td>
#       <td>0.319737</td>
#       <td>0.565453</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.191400</td>
#       <td>0.305984</td>
#       <td>0.553158</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.191400</td>
#       <td>0.313175</td>
#       <td>0.559620</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 3:
#     <div>
#
#       <progress value='2024' max='2024' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2024/2024 20:57, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.725243</td>
#       <td>0.851612</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.555207</td>
#       <td>0.745122</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.552666</td>
#       <td>0.743415</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.469641</td>
#       <td>0.685304</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.411600</td>
#       <td>0.588652</td>
#       <td>0.767237</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.411600</td>
#       <td>0.459256</td>
#       <td>0.677684</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.411600</td>
#       <td>0.575464</td>
#       <td>0.758594</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.411600</td>
#       <td>0.453972</td>
#       <td>0.673775</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.411600</td>
#       <td>0.535899</td>
#       <td>0.732051</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.255600</td>
#       <td>0.433938</td>
#       <td>0.658740</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.255600</td>
#       <td>0.452049</td>
#       <td>0.672346</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.255600</td>
#       <td>0.453282</td>
#       <td>0.673262</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.255600</td>
#       <td>0.461914</td>
#       <td>0.679642</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.255600</td>
#       <td>0.461379</td>
#       <td>0.679249</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.186000</td>
#       <td>0.460868</td>
#       <td>0.678872</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.186000</td>
#       <td>0.448036</td>
#       <td>0.669355</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.186000</td>
#       <td>0.440398</td>
#       <td>0.663625</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.186000</td>
#       <td>0.453014</td>
#       <td>0.673063</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.186000</td>
#       <td>0.443896</td>
#       <td>0.666255</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.127500</td>
#       <td>0.445067</td>
#       <td>0.667134</td>
#     </tr>
#   </tbody>
# </table><p>
# fold 0:
# fold 1:
# fold 2:
# fold 3:
# cv wording rmse: 0.6266705883625747
# fold 0:
# fold 1:
# fold 2:
# fold 3:

# %%
CFG.model_name
# Out:
# 'debertav3base'

# %%
#model_dir

# %%
#!zip -r working.zip /kaggle/working/

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tqdm import tqdm
import os
import zipfile
from zipfile import ZipFile
import shutil
import pickle
import nltk
from nltk.tokenize import sent_tokenize
import shap

import sys
sys.path.append('/kaggle/input/sentence-transformers-222/sentence-transformers')
from sentence_transformers import SentenceTransformer, models
st_model = SentenceTransformer('/kaggle/input/sentence-transformers-222/all-MiniLM-L6-v2')

# !pip install "/kaggle/input/language-tool-python/language_tool_python-2.7.1-py3-none-any.whl"

# create download path
def get_language_tool_cache_path():
    # Get download path from environment or use default.
    download_path = os.environ.get(
        'LTP_PATH',
        os.path.join(os.path.expanduser("~"), ".cache", "language_tool_python")
    )
    # Make download path, if it doesn't exist.
    os.makedirs(download_path, exist_ok=True)
    return download_path

lt_path = get_language_tool_cache_path()
lt_path

#cant move files directly from input to cache, so we zip it to output and unzip again


def get_all_file_paths(directory):
  
    # initializing empty file paths list
    file_paths = []
  
    # crawling through directory and subdirectories
    for root, directories, files in os.walk(directory):
        for filename in files:
            # join the two strings in order to form the full filepath.
            filepath = os.path.join(root, filename)
            file_paths.append(filepath)
  
    # returning all file paths
    return file_paths        
  
def main():
    # path to folder which needs to be zipped
    directory = '/kaggle/input/languagetool57imroze/LanguageTool-5.7'
  
    # calling function to get all file paths in the directory
    file_paths = get_all_file_paths(directory)

    # writing files to a zipfile
    with ZipFile('./lt.zip','w') as zip:
        # writing each file one by one
        for file in file_paths:
            zip.write(file)
  
    print('All files zipped successfully!')        
  
main()


 
zip_file = "./lt.zip"
 
try:
    with zipfile.ZipFile(zip_file) as z:
        z.extractall()
        print("Extracted all")
except:
    print("Invalid file")
    
#move to cache
# !mv {'/kaggle/input/languagetool57imroze/LanguageTool-5.7'} {lt_path} 
os.listdir('/root/.cache/language_tool_python/')

os.remove('/kaggle/working/lt.zip')

import language_tool_python
tool = language_tool_python.LanguageTool('en-US')

# !pip install "/kaggle/input/autocorrect/autocorrect-2.6.1.tar"
# !pip install "/kaggle/input/pyspellchecker/pyspellchecker-0.7.2-py3-none-any.whl"
# !pip install "/kaggle/input/textstat-pypi/Pyphen-0.9.3-py2.py3-none-any.whl"
# !pip install "/kaggle/input/textstat-pypi/textstat-0.7.0-py3-none-any.whl"
# Out:
# Processing /kaggle/input/language-tool-python/language_tool_python-2.7.1-py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from language-tool-python==2.7.1) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from language-tool-python==2.7.1) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->language-tool-python==2.7.1) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->language-tool-python==2.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->language-tool-python==2.7.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->language-tool-python==2.7.1) (2023.5.7)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-2.7.1
# All files zipped successfully!
# Extracted all
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/testrules.sh': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-de/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-de/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-zh/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-zh/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ro/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ro/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ar/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ar/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-all/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-all/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-nl/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-nl/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sk/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sk/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-tl/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-tl/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ta/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ta/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sl/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sl/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-en/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-en/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ga/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ga/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-pl/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-pl/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ca/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ca/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-de-DE-x-simple-language/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-de-DE-x-simple-language/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-fa/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-fa/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-it/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-it/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-fr/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-fr/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-km/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-km/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-uk/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-uk/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-es/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-es/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ja/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ja/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-gl/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-gl/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-el/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-el/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ru/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ru/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sv/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-sv/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-br/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-br/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-be/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-be/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ast/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-ast/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-da/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-da/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-eo/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-eo/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-pt/pom.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/maven/org.languagetool/language-pt/pom.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/MANIFEST.MF': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/META-INF/org/languagetool/language-module.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/CHANGES.md': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/languagetool.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/COPYING.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/README.md': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/CPL.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/segment-license.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/MIT.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/LGPL-2.1.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/CC-Attr-SA-4.0.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/Morfologik-license.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/MIT-slf4j.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/BSD.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/Apache-License.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/third-party-licenses/icons.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/CHANGES.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/languagetool-commandline.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/testrules.bat': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/languagetool-server.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jackson-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/resilience4j-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/ecs-logging-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/hamcrest-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-resolver.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/slf4j-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/resilience4j-micrometer.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/languagetool-core-tests.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_tracer_otel.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/lucene-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/istack-commons-runtime.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_guava.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/german-pos-dict.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-tcnative-classes.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-webapp.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jaxb-runtime.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-context.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/catalan-pos-dict.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/mybatis.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/guava.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_common.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/indriya.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jsr305.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/resilience4j-circuitbreaker.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/emoji-java.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-util.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/language-detector.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/websocket-client.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_tracer_otel_agent.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/j2objc-annotations.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/javax.activation-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-buffer.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-pool2.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/opennlp-tokenize-models.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/reactor-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/lettuce-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/bcrypt.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-common.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/junit.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jackson-annotations.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/uom-lib-common.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/javax.annotation-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/websocket-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/javax.servlet-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/spark-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-fsa.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/trove4j.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/logback-classic.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/unit-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/hppc.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/languagetool-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_hotspot.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/perfmark-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-beanutils.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/listenablefuture.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/logback-ecs-encoder.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/error_prone_annotations.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-stub.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/openregex.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-collections4.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-xml.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-codec.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_tracer_common.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-fsa-builders.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/aho-corasick-double-array-trie.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jsonic.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-security.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/icu4j.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-http.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/opennlp-tools.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/lucene-backward-codecs.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/gson.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/logback-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-io.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-protobuf.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-server.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/proto-google-common-protos.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/vavr-match.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jaxb-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/java-jwt.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/FastInfoset.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/annotations.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/hanlp.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-lang3.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-stemming.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-logging.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/mariadb-java-client.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-ukrainian-lt.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/failureaccess.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/websocket-servlet.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jackson-databind.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-tools.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-handler.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/languagetool-ga-dicts.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/websocket-server.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/reactive-streams.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jcommander.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-text.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/lucene-gosen-ipadic.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/opennlp-postag-models.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-protobuf-lite.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/checker-qual.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/dx.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morfologik-speller.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/vavr.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-cli.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/HdrHistogram.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/languagetool-tools.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-client.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-digester.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/spanish-pos-dict.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/hunspell.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-codec.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/stax-ex.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/languagetool-gui-commons.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-io.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jwordsplitter.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/websocket-common.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/bridj.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/LatencyUtils.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/protobuf-java.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/json.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/morphology-el.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jaxb-api.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/opennlp-chunk-models.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/segment.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/netty-transport.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/txw2.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-servlet.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/bytes.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/jetty-util-ajax.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/micrometer-registry-prometheus.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/french-pos-dict.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/grpc-netty-shaded.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/micrometer-core.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/simpleclient_httpserver.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/libs/commons-validator.jar': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/it/ItalianSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/GermanSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/ar/ArabicSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/ro/RomanianSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/sk/SlovakSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/es/SpanishSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/nl/DutchSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/FrenchSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/el/GreekSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/pt/PortugueseSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/uk/UkrainianSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/ru/RussianSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/ca/CatalanSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/ga/IrishSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/gl/GalicianSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/pl/PolishSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/synthesis/en/EnglishSynthesizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_ro.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_br.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_fr.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_tl.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_uk.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/italian_tags.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/confusion_sets.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/hunspell/README_it_IT.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/hunspell/it_IT.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/hunspell/it_IT.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/disambiguation.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/not_smi.awk': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/tagset.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/italian_synth.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/italian_synth.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/morph_data_italian.awk': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/italian.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/it/italian.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/LICENSES-en.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/ast_ES.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/ast_ES.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/hunspell/LICENCES-ast.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/ast.profile.README': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/asturian.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/ast.profile': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ast/asturian.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/tagalog.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/README_frequencies.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/README_tl_PH.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/tl_PH.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/tl_PH.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/tagset.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/tagalog.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/tl/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/compounds.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/LICENSE_sv_SE.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/LICENSE_en_US.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/sv_SE.dic': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/hunspell/sv_SE.aff': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/tagset.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/swedish.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/sv/swedish.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/tamil.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/tamil.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/tagset.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/ta/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/hunspell/da_DK.dic': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/hunspell/README_da_DK.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/hunspell/da_DK.aff': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/disambiguation.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/tagset.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/removed.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/added.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/danish.dict': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/added_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/README.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/removed_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/da/danish.info': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/zh/common_words.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/zh/confusion_sets.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/LICENSES-en.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/LICENCES-km.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/km_KH.dic': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/ignore.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/km_KH.aff': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/hunspell/spelling.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/disambiguation.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/khmertags.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/resource/km/khmer.info': Read-only file system
# ...
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/det_an.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/CompoundRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/MorfologikNewZealandSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishPlainEnglishRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/grammar-l2-de.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/BritishReplaceRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishForFrenchFalseFriendRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/UpperCaseNgramRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/ContractionSpellingRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/OrdinalSuffixFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishWordRepeatBeginningRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AvsAnData.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishSuppressMisspelledSuggestionsFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AvsAnRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/DateCheckFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/wrongWordInContext.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/NewZealandReplaceRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishUnpairedBracketsRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishNumberInWordFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AdvancedSynthesizerFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/WordCoherencyRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AmericanReplaceRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/FindSuggestionsFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-US/grammar.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-US/replace.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/det_a.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/MorfologikCanadianSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AdverbFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishRedundancyRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AdverbFilter$1.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/VariantInfo.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishForGermansFalseFriendRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishSpecificCaseRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/MorfologikAmericanSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AbstractEnglishSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishForL2SpeakersFalseFriendRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AbstractEnglishSpellerRule$1.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AvsAnRule$Determiner.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishDashRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/MorfologikSouthAfricanSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishNgramProbabilityRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/coherency.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/DateFilterHelper.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/UnitConversionRuleImperial.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/UnitConversionRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishPartialPosTagFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/grammar-l2-fr.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/YMDNewYearDateFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-GB/grammar.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-GB/replace.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/NoDisambiguationEnglishPartialPosTagFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/diacritics.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/wordiness.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/indent.sh': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/grammar.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/AbstractEnglishSpellerRule$IrregularForms.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishRepeatedWordsRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishWordRepeatRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/NewYearDateFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/synonyms.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/ConvertToSentenceCaseFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/GoogleStyleWordTokenizer.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/contractions.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/ConsistentApostrophesRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/redundancies.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/replace.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/MorfologikBritishSpellerRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-AU/grammar.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/SimpleReplaceRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/UnitConversionRuleUS.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/YMDDateCheckFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishForSpaniardsFalseFriendRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/replace_custom.txt': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishForDutchmenFalseFriendRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/en-CA/grammar.xml': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishWrongWordInContextRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/FutureDateFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishConfusionProbabilityRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/EnglishDiacriticsRule.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/translation/BeoLingusTranslator.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/rules/en/translation/Inflector.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/EnglishChunker.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/RussianChunker$AffectedSpans.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/RussianChunker$Span.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/GermanChunker$AffectedSpans.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/EnglishChunkFilter.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/TokenExpressionFactory.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/GermanChunker$RegularExpressionWithPhraseType.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/GermanChunker$Span.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/RussianChunker$RegularExpressionWithPhraseType.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/GermanChunker.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/TokenExpressionFactory$1.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/GermanChunker$PhraseType.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/EnglishChunkFilter$ChunkType.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/RussianChunker.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/RussianChunker$PhraseType.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/chunking/TokenPredicate.class': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_el.properties': Read-only file system
# mv: cannot remove '/kaggle/input/languagetool57imroze/LanguageTool-5.7/org/languagetool/MessagesBundle_km.properties': Read-only file system
# Processing /kaggle/input/autocorrect/autocorrect-2.6.1.tar
# done
# Building wheels for collected packages: autocorrect
# done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622383 sha256=3358e48fa877beb96434e5b8b7eaf2c5d44869388cb868ce53bc11d0a7c29767
#   Stored in directory: /root/.cache/pip/wheels/db/69/42/0fb0421d2fe70d195a04665edc760cfe5fd341d7bb8d8e0aaa
# Successfully built autocorrect
# Installing collected packages: autocorrect
#   Attempting uninstall: autocorrect
#     Found existing installation: autocorrect 2.6.1
#     Uninstalling autocorrect-2.6.1:
#       Successfully uninstalled autocorrect-2.6.1
# Successfully installed autocorrect-2.6.1
# Processing /kaggle/input/pyspellchecker/pyspellchecker-0.7.2-py3-none-any.whl
# pyspellchecker is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing /kaggle/input/textstat-pypi/Pyphen-0.9.3-py2.py3-none-any.whl
# Installing collected packages: Pyphen
# Successfully installed Pyphen-0.9.3
# Processing /kaggle/input/textstat-pypi/textstat-0.7.0-py3-none-any.whl
# Requirement already satisfied: pyphen in /opt/conda/lib/python3.10/site-packages (from textstat==0.7.0) (0.9.3)
# Installing collected packages: textstat
# Successfully installed textstat-0.7.0

# %%
df_train_p=pd.read_csv("/kaggle/input/commonlit-evaluate-student-summaries/prompts_train.csv")
df_train_s=pd.read_csv("/kaggle/input/commonlit-evaluate-student-summaries/summaries_train.csv")

df_train_s=pd.read_csv("/kaggle/input/commonlit-evaluate-student-summaries/summaries_train.csv")

from textblob import TextBlob

def spell_correction_tb(text):
    text = TextBlob(text)
    result = text.correct()
    return str(result)

from autocorrect import Speller
from spellchecker import SpellChecker
from typing import List

speller = Speller(lang='en')
spellchecker = SpellChecker()

def spelling(text):
    wordlist=text.split()
    amount_miss = len(list(spellchecker.unknown(wordlist)))
    return amount_miss

def add_spelling_dictionary(tokens: List[str]) -> List[str]:
    """dictionary update for pyspell checker and autocorrect"""
    spellchecker.word_frequency.load_words(tokens)
    speller.nlp_data.update({token:1000 for token in tokens})
    
import spacy
nlp = spacy.load("en_core_web_sm")

def get_coherence_complexities(text):
    doc = nlp(text)
    # Calculate the average sentence length
    #num_sentences = len(list(doc.sents))
    num_sentences = len(sent_tokenize(text.replace(".",". ")))
    num_words = len(doc)
    avg_sentence_length = num_words / num_sentences
    # Calculate the coherence of discourse
    num_connectives = len([token for token in doc if token.dep_ == "mark"])
    try:
        #coherence = num_connectives / (num_sentences - 1)
        coherence = num_connectives / (num_sentences)
    except ZeroDivisionError:
        coherence = 0
    # Calculate the lexical and grammatical complexity
    num_named_entities = len(doc.ents)
    num_dependent_clauses = len([token for token in doc if token.dep_ == "mark" or token.dep_ == "advcl"])
    num_compound_nouns = len([token for token in doc if token.pos_ == "NOUN" and token.dep_ == "compound"])
    num_proper_nouns = len([token for token in doc if token.pos_ == "PROPN"])
    num_adjectives = len([token for token in doc if token.pos_ == "ADJ"])
    num_adverbs = len([token for token in doc if token.pos_ == "ADV"])
    num_prepositions = len([token for token in doc if token.pos_ == "ADP"])
    num_conjunctions = len([token for token in doc if token.pos_ == "CCONJ"])
    num_pronouns = len([token for token in doc if token.pos_ == "PRON"])
    lexical_complexity = (num_named_entities + num_dependent_clauses + num_compound_nouns + num_proper_nouns + num_adjectives + num_adverbs) / num_words
    grammatical_complexity = (num_prepositions + num_conjunctions + num_pronouns) / num_words
    
    return (coherence,lexical_complexity,grammatical_complexity)

import textstat

def text_complexity(text):
    score=textstat.flesch_reading_ease(text)
    if(score>=0 and score<=29):
        #print("Very Confusing")
        return ([score,"Very Confusing"])
    elif(score>=30 and score<=49):
        #print("Difficult")
        return ([score,"Difficult"])
    elif(score>=50 and score<=59):
        #print("Fairly Difficult")
        return ([score,"Fairly Difficult"])
    elif(score>=60 and score<=69):
        #print("Standard")
        return ([score,"Standard"])
    elif(score>=70 and score<=79):
        #print("Fairly Easy")
        return ([score,"Fairly Easy"])
    elif(score>=80 and score<=89):
        #print("Easy")
        return ([score,"Easy"])
    elif(score>=90 and score<=100):
        #print("Very Easy")
        return ([score,"Very Easy"])
    return ([0,'Very Confusing'])


def spelling_grammar_mistakes(text):
    spelling_counts=0
    grammar_counts=0
    matches = tool.check(str(text))
    
    for i in range(len(matches)):
        #print('matches',i,matches[i])
        if(matches[i].ruleId=='MORFOLOGIK_RULE_EN_US'):
            """
            cntxt = list(matches[i].context)
            cntxt[matches[i].offset]='>'
            s = ''
            for v in cntxt:
                s+=v
            print(s)
            """
            spelling_counts+=1
        else:
            grammar_counts+=1
            
    return {'spelling_errors':spelling_counts,'grammar_errors':grammar_counts}

# %%
def extract_answer_features(input_answer):
    input_answer = input_answer.lower()
    tokenized_sentences = sent_tokenize(input_answer.replace(".",". "))
    #print(tokenized_sentences)
    num_sentences = len(tokenized_sentences)
    senten_lens = [ len(cur_sent.split(' ')) for cur_sent in tokenized_sentences ]
    #print(senten_lens)
    res = spelling_grammar_mistakes(input_answer)
    spelling_errors = float(res['spelling_errors']) / float(num_sentences)
    grammar_errors = float(res['grammar_errors']) / float(num_sentences)
    #input_answer_FTBSL = spell_correction_tb(input_answer)
    input_answer_FTBSL = speller(input_answer)
    #print(input_answer_FTBSL)
    answer_ts_complexity = text_complexity(input_answer_FTBSL)
    answer_ts_difficwords = textstat.difficult_words(input_answer_FTBSL)
    coherence,lexical_complexity,grammatical_complexity = get_coherence_complexities(input_answer_FTBSL)
    answer_len = len(input_answer_FTBSL.split(' '))
    feat_dict = dict()
    feat_dict['coherence']=coherence
    feat_dict['syl_complexity']=answer_ts_complexity[0]
    feat_dict['lex_complexity']=lexical_complexity
    feat_dict['gramm_complexity']=grammatical_complexity
    feat_dict['diffic_words']=answer_ts_difficwords / float(num_sentences)
    feat_dict['spelling_errors']=spelling_errors / float(num_sentences)
    feat_dict['grammar_errors']=grammar_errors / float(num_sentences)
    feat_dict['num_sentences']=num_sentences
    feat_dict['answer_len']=answer_len
    feat_dict['senten_len_max']=max(senten_lens)
    feat_dict['senten_len_min']=min(senten_lens)
    feat_dict['senten_len_avg']=np.mean(senten_lens)
    
    return feat_dict


def extract_answer_features2(input_answer,prompt_question,prompt_text):
    input_answer = input_answer.lower()
    tokenized_sentences = sent_tokenize(input_answer.replace(".",". ").replace("  ","."))
    #print(tokenized_sentences)
    num_sentences = len(tokenized_sentences)
    senten_lens = [ len(cur_sent.split(' ')) for cur_sent in tokenized_sentences ]
    #print(senten_lens)
    res = spelling_grammar_mistakes(input_answer)
    spelling_errors = float(res['spelling_errors']) / float(num_sentences)
    grammar_errors = float(res['grammar_errors']) / float(num_sentences)
    #input_answer_FTBSL = spell_correction_tb(input_answer)
    input_answer_FTBSL = speller(input_answer)
    #print(input_answer_FTBSL)
    answer_ts_complexity = text_complexity(input_answer_FTBSL)
    answer_ts_difficwords = textstat.difficult_words(input_answer_FTBSL)
    coherence,lexical_complexity,grammatical_complexity = get_coherence_complexities(input_answer_FTBSL)
    answer_len = len(input_answer_FTBSL.split(' '))
    
    ans_words_list = word_tokenize(input_answer_FTBSL.replace(".","").replace(",","").replace("  ",""))
    prompt_words_list = word_tokenize(prompt_text.replace(".","").replace(",","").replace("  ",""))
    ans_words_set = set(ans_words_list)
    prompt_words_set = set(prompt_words_list)
    
    self_novelty = len(ans_words_set)/len(ans_words_list)
    novelty = len(ans_words_set.difference(prompt_words_set))
    
    rg1 = -10
    rg2 = -10
    rgL = -10
    try:
        rg1,rg2,rgL = get_rogue_f1s(prompt_text,input_answer_FTBSL)
    except:
        pass
    
    try:
        self_bleu_score = self_bleu(input_answer_FTBSL)
    except:
        self_bleu_score = -10
        
    rg1S = -10
    rg2S = -10
    rgLS = -10
    try:
        rg1S,rg2S,rgLS = get_avg_self_rogues(input_answer_FTBSL)
    except:
        pass
    
    len_ratio = len(prompt_text)/len(input_answer)
    
    feat_dict = dict()
    feat_dict['coherence']=coherence
    feat_dict['syl_complexity']=answer_ts_complexity[0]
    feat_dict['lex_complexity']=lexical_complexity
    feat_dict['gramm_complexity']=grammatical_complexity
    feat_dict['diffic_words']=answer_ts_difficwords / float(num_sentences)
    feat_dict['spelling_errors']=spelling_errors / float(num_sentences)
    feat_dict['grammar_errors']=grammar_errors / float(num_sentences)
    feat_dict['num_sentences']=num_sentences
    feat_dict['answer_len']=answer_len
    feat_dict['senten_len_max']=max(senten_lens)
    feat_dict['senten_len_min']=min(senten_lens)
    feat_dict['senten_len_avg']=np.mean(senten_lens)
    feat_dict['senten_len_std']=np.std(senten_lens)
    
    feat_dict['self_novelty']=self_novelty
    feat_dict['novelty']=novelty
    feat_dict['rg1']=rg1
    feat_dict['rg2']=rg2
    feat_dict['rgL']=rgL
    feat_dict['rg1S']=rg1S
    feat_dict['rg2S']=rg2S
    feat_dict['rgLS']=rgLS
    feat_dict['self_bleu']=self_bleu_score
    feat_dict['len_ratio']=len_ratio
    
    return feat_dict


# 'self_bleu','self_novelty','novelty','rg1','rgL','len_ratio'

# %%
#df_train_s = pd.read_csv('/kaggle/input/summaries-nlp-features/summaries_nlp_feats.csv')
df_train_s = pd.read_csv('/kaggle/input/summaries-nlp-features-v2/summaries_nlp_feats3.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, cross_val_score

# %%
import lightgbm as lgb

df = df_train_s


X = df[['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']]

"""
X = df[['syl_complexity', 'lex_complexity', 'gramm_complexity','spelling_errors', 'grammar_errors']]
"""

#X = df[['syl_complexity', 'lex_complexity', 'gramm_complexity', 'grammar_errors', 'answer_len','senten_len_avg']]


y = df['wording']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

dtrain = lgb.Dataset(X_train, label=y_train)
dval = lgb.Dataset(X_test, label=y_test)

params = {
    'boosting_type': 'gbdt',
    'random_state': 42,
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.05, #0.06
    'max_depth': 5,  #5
    'lambda_l1': 0.0,
    'lambda_l2': 0.005 #0.006
}

evaluation_results = {}
model_wording = lgb.train(params,
                  num_boost_round=10000,
                    #categorical_feature = categorical_features,
                  valid_names=['train', 'valid'],
                  train_set=dtrain,
                  valid_sets=dval,
                  callbacks=[
                      lgb.early_stopping(stopping_rounds=40, verbose=False),
                       lgb.log_evaluation(100),
                      lgb.callback.record_evaluation(evaluation_results)
                    ],
                  )

# Predictions
y_pred = model_wording.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(i,f"Mean Squared Error: {mse:.3f}")
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000890 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2119
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 12
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.061884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.762775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	train's rmse: 0.756996
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 3 Mean Squared Error: 0.569

# %%
df = df_train_s
X = df[['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']]
y = df['content']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, random_state=42)

dtrain = lgb.Dataset(X_train, label=y_train)
dval = lgb.Dataset(X_test, label=y_test)

params = {
    'boosting_type': 'gbdt',
    'random_state': 42,
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.05, #0.048 0.06
    'max_depth': 3,  #4
    'lambda_l1': 0.0,
    'lambda_l2': 0.01 #0.011
}

evaluation_results = {}
model_content = lgb.train(params,
                  num_boost_round=10000,
                    #categorical_feature = categorical_features,
                  valid_names=['train', 'valid'],
                  train_set=dtrain,
                  valid_sets=dval,
                  callbacks=[
                      lgb.early_stopping(stopping_rounds=40, verbose=False),
                       lgb.log_evaluation(100),
                      lgb.callback.record_evaluation(evaluation_results)
                    ],
                  )

# Predictions
y_pred = model_content.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(i,f"Mean Squared Error: {mse:.3f}")
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1865
# [LightGBM] [Info] Number of data points in the train set: 6806, number of used features: 11
# [LightGBM] [Info] Start training from score -0.011564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.543438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	train's rmse: 0.535647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 3 Mean Squared Error: 0.285

# %%
prompts_test
# Out:
#   prompt_id prompt_question     prompt_title       prompt_text  prompt_length  \
# 0    abc123    Summarize...  Example Title 1  Heading\nText...              3
# 1    def789    Summarize...  Example Title 2  Heading\nText...              3
#
#           prompt_tokens
# 0  [Heading, Text, ...]
# 1  [Heading, Text, ...]

# %%
prompt_dict = dict()

for i in range(len(prompts_test)):
    pid = prompts_test['prompt_id'].iloc[i]
    pttl = prompts_test['prompt_question'].iloc[i]
    ptxt = prompts_test['prompt_text'].iloc[i]
    prompt_dict[pid] = [pttl,ptxt]

# %%
list(prompt_dict.keys())
# Out:
# ['abc123', 'def789']

# %%
sample_submission = pd.read_csv("/kaggle/input/commonlit-evaluate-student-summaries/sample_submission.csv")
test_df = pd.read_csv("/kaggle/input/commonlit-evaluate-student-summaries/summaries_test.csv")

ss = 'He is goeng home. He will riturn soon.'
ss2 = 'He is goeng home. He will not riturn soon.'
feat_dict = extract_answer_features2(ss,ss2,ss2)

feat_dict_data = { k:[] for k in list(feat_dict.keys())  }
for i in tqdm(range( len(test_df) )) :
    text = test_df['text'].iloc[i]
    #feat_dict = extract_answer_features(text)
    pid = test_df['prompt_id'].iloc[i]
    prompt_question = prompt_dict[pid][0]
    prompt_text = prompt_dict[pid][1]
    feat_dict = extract_answer_features2(text,prompt_question,prompt_text)
    for k in list(feat_dict.keys()):
        feat_dict_data[k].append( feat_dict[k] )
        
for k in list(feat_dict_data.keys()):
    test_df[k] = feat_dict_data[k]
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 12.00it/s]

# %%
content_preds = []
for i in tqdm(range(len(test_df))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(test_df[k].iloc[i])  )
    pred = float(model_content.predict( np.array([feats]) )[0])
    content_preds.append(pred)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 1457.24it/s]

# %%
wording_preds = []
for i in tqdm(range(len(test_df))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(test_df[k].iloc[i])  )
    pred = float(model_wording.predict( np.array([feats]) )[0])
    wording_preds.append(pred)
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 1815.72it/s]

# %%
test_df['content_preds'] = content_preds
test_df['wording_preds'] = wording_preds
sample_submission['content'] = test_df['content_preds'].values
sample_submission['wording'] = test_df['wording_preds'].values

# %%
sample_submission
# Out:
#      student_id   content   wording
# 0  000000ffffff -1.497897 -0.812235
# 1  111111eeeeee -1.497897 -0.812235
# 2  222222cccccc -1.497897 -0.812235
# 3  333333dddddd -1.497897 -0.812235

# %%
# !rm -r {lt_path}

# %%
try:
    shutil.rmtree('/kaggle/working/kaggle/input/languagetool57imroze/LanguageTool-5.7')
    shutil.rmtree('/kaggle/working/kaggle/input')
except:
    print('exception 1')

# %%
try:
    shutil.rmtree('/kaggle/working/rouge_score-0.1.2')
except:
    print('exception 2')

# %%
try:
    shutil.rmtree('/kaggle/working/rouge_score-0.1.2')
except:
    print('exception 3')
# Out:
# exception 3

# %%
try:
    shutil.rmtree('/kaggle/working/debertav3base')
except:
    print('exception 4')

# %% [markdown]
# # LGB MODEL

# %%
train.head(3)
# Out:
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
#
#     content   wording  summary_length  \
# 0  0.205683  0.380538              64
# 1 -0.548304  0.506755              54
# 2  3.128928  4.231226             269
#
#                                   fixed_summary_text  splling_err_num  \
# 0  The third wave was an experimental see how peo...                5
# 1  They would rub it up with soda to make the sme...                2
# 2  In Egypt, there were many occupations and soci...               32
#
#                                      prompt_question  \
# 0  Summarize how the Third Wave developed over su...
# 1  Summarize the various ways the factory would u...
# 2  In complete sentences, summarize the structure...
#
#                 prompt_title  ... prompt_length  word_overlap_count  \
# 0             The Third Wave  ...           660                  14
# 1    Excerpt from The Jungle  ...          1076                  18
# 2  Egyptian Social Structure  ...           625                  22
#
#    bigram_overlap_count  bigram_overlap_ratio  trigram_overlap_count  \
# 0                     4              0.063492                      0
# 1                    22              0.415094                     10
# 2                    52              0.194030                     23
#
#    trigram_overlap_ratio  quotes_count  fold  content_pred  wording_pred
# 0               0.000000             0   3.0     -0.030020      0.686377
# 1               0.192308             0   2.0     -0.722237     -0.250455
# 2               0.086142             2   1.0      2.439310      1.904997
#
# [3 rows x 21 columns]

# %%
test.head(3)
# Out:
#      student_id prompt_id            text  summary_length fixed_summary_text  \
# 0  000000ffffff    abc123  Example text 1               3     Example text 1
# 1  111111eeeeee    def789  Example text 2               3     Example text 2
# 2  222222cccccc    abc123  Example text 3               3     Example text 3
#
#    splling_err_num prompt_question     prompt_title       prompt_text  \
# 0                0    Summarize...  Example Title 1  Heading\nText...
# 1                0    Summarize...  Example Title 2  Heading\nText...
# 2                0    Summarize...  Example Title 1  Heading\nText...
#
#    prompt_length  ...  content_pred_0  content_pred_1  content_pred_2  \
# 0              3  ...       -1.521437       -1.609047       -1.402371
# 1              3  ...       -1.523067       -1.611609       -1.403302
# 2              3  ...       -1.541403       -1.616524       -1.407259
#
#    content_pred_3   content  wording_pred_0 wording_pred_1  wording_pred_2  \
# 0       -1.300265 -1.458280       -1.459463      -1.425489       -1.339818
# 1       -1.294887 -1.458216       -1.468567      -1.424382       -1.352623
# 2       -1.313284 -1.469617       -1.454117      -1.441295       -1.352539
#
#    wording_pred_3   wording
# 0       -1.385726 -1.402624
# 1       -1.389704 -1.408819
# 2       -1.390533 -1.409621
#
# [3 rows x 27 columns]

# %%
df_train_s.head(3)
# Out:
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
#
#     content   wording  coherence  syl_complexity  lex_complexity  \
# 0  0.205683  0.380538   0.500000           18.02        0.281250
# 1 -0.548304  0.506755   0.000000           61.00        0.145455
# 2  3.128928  4.231226   0.166667            0.00        0.152727
#
#    gramm_complexity  diffic_words  ...  self_novelty  novelty       rg1  \
# 0          0.156250          11.0  ...      0.803279       26  0.114804
# 1          0.290909           3.0  ...      0.673077        2  0.095238
# 2          0.210909          38.0  ...      0.587500       74  0.407547
#
#         rg2       rgL      rg1S      rg2S      rgLS  self_bleu  len_ratio
# 0  0.024242  0.072508  0.197580  0.000000  0.163741   0.459545  10.306358
# 1  0.044791  0.073858  0.307692  0.080000  0.192308   0.264532  21.049180
# 2  0.100883  0.206289  0.157057  0.005565  0.122904   0.644615   2.441606
#
# [3 rows x 28 columns]

# %%
test_df.head(3)
# Out:
#      student_id prompt_id            text  coherence  syl_complexity  \
# 0  000000ffffff    abc123  Example text 1        0.0               0
# 1  111111eeeeee    def789  Example text 2        0.0               0
# 2  222222cccccc    abc123  Example text 3        0.0               0
#
#    lex_complexity  gramm_complexity  diffic_words  spelling_errors  \
# 0        0.333333               0.0           1.0              0.0
# 1        0.333333               0.0           1.0              0.0
# 2        0.333333               0.0           1.0              0.0
#
#    grammar_errors  ...  rg1  rg2  rgL  rg1S  rg2S  rgLS  self_bleu  len_ratio  \
# 0             1.0  ...  0.4  0.0  0.4   NaN   NaN   NaN        -10   1.071429
# 1             1.0  ...  0.4  0.0  0.4   NaN   NaN   NaN        -10   1.071429
# 2             1.0  ...  0.4  0.0  0.4   NaN   NaN   NaN        -10   1.071429
#
#    content_preds  wording_preds
# 0      -1.497897      -0.812235
# 1      -1.497897      -0.812235
# 2      -1.497897      -0.812235
#
# [3 rows x 28 columns]

# %%
#cols2use = ['coherence', 'syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words', 'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len', 'senten_len_max', 'senten_len_min', 'senten_len_avg']

# %%
#cols2use = ['syl_complexity', 'lex_complexity', 'gramm_complexity', 'grammar_errors','diffic_words', 'spelling_errors']

# %%
#cols2use = ['syl_complexity', 'lex_complexity', 'gramm_complexity', 'grammar_errors','diffic_words', 'spelling_errors', 'self_bleu','self_novelty','novelty','rg1','rgL']

# %%
cols2use = ['syl_complexity', 'lex_complexity', 'gramm_complexity', 'grammar_errors','diffic_words', 'spelling_errors', 'self_bleu','self_novelty']

# %%
#,'len_ratio'

# %%
for colname in cols2use:
    train[colname] = df_train_s[colname].values
    test[colname] = test_df[colname].values

# %%
"""
content_preds = []
for i in tqdm(range(len(train))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(train[k].iloc[i])  )
    pred = float(model_content.predict( np.array([feats]) )[0])
    content_preds.append(pred)
    
    
wording_preds = []
for i in tqdm(range(len(train))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(train[k].iloc[i])  )
    pred = float(model_wording.predict( np.array([feats]) )[0])
    wording_preds.append(pred)
    
    
train['content_preds2'] = content_preds
train['wording_preds2'] = wording_preds


content_preds = []
for i in tqdm(range(len(test))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(test[k].iloc[i])  )
    pred = float(model_content.predict( np.array([feats]) )[0])
    content_preds.append(pred)
    
    
wording_preds = []
for i in tqdm(range(len(test))):
    feats = []
    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',
        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',
        'senten_len_max', 'senten_len_min', 'senten_len_avg']:
        feats.append( float(test[k].iloc[i])  )
    pred = float(model_wording.predict( np.array([feats]) )[0])
    wording_preds.append(pred)
    
    
test['content_preds2'] = content_preds
test['wording_preds2'] = wording_preds
"""
# Out:
# "\ncontent_preds = []\nfor i in tqdm(range(len(train))):\n    feats = []\n    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',\n        'spelling_errors', 'grammar_errors', 'num_sentences',\n        'senten_len_max', 'senten_len_min', 'senten_len_avg']:\n        feats.append( float(train[k].iloc[i])  )\n    pred = float(model_content.predict( np.array([feats]) )[0])\n    content_preds.append(pred)\n    \n    \nwording_preds = []\nfor i in tqdm(range(len(train))):\n    feats = []\n    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',\n        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',\n        'senten_len_max', 'senten_len_min', 'senten_len_avg']:\n        feats.append( float(train[k].iloc[i])  )\n    pred = float(model_wording.predict( np.array([feats]) )[0])\n    wording_preds.append(pred)\n    \n    \ntrain['content_preds2'] = content_preds\ntrain['wording_preds2'] = wording_preds\n\n\ncontent_preds = []\nfor i in tqdm(range(len(test))):\n    feats = []\n    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',\n        'spelling_errors', 'grammar_errors', 'num_sentences',\n        'senten_len_max', 'senten_len_min', 'senten_len_avg']:\n        feats.append( float(test[k].iloc[i])  )\n    pred = float(model_content.predict( np.array([feats]) )[0])\n    content_preds.append(pred)\n    \n    \nwording_preds = []\nfor i in tqdm(range(len(test))):\n    feats = []\n    for k in ['coherence','syl_complexity', 'lex_complexity', 'gramm_complexity', 'diffic_words',\n        'spelling_errors', 'grammar_errors', 'num_sentences', 'answer_len',\n        'senten_len_max', 'senten_len_min', 'senten_len_avg']:\n        feats.append( float(test[k].iloc[i])  )\n    pred = float(model_wording.predict( np.array([feats]) )[0])\n    wording_preds.append(pred)\n    \n    \ntest['content_preds2'] = content_preds\ntest['wording_preds2'] = wording_preds\n"

# %%
#train['wording2'] = df_train_s['wording'].values

# %%
test
# Out:
#      student_id prompt_id            text  summary_length fixed_summary_text  \
# 0  000000ffffff    abc123  Example text 1               3     Example text 1
# 1  111111eeeeee    def789  Example text 2               3     Example text 2
# 2  222222cccccc    abc123  Example text 3               3     Example text 3
# 3  333333dddddd    def789  Example text 4               3     Example text 4
#
#    splling_err_num prompt_question     prompt_title       prompt_text  \
# 0                0    Summarize...  Example Title 1  Heading\nText...
# 1                0    Summarize...  Example Title 2  Heading\nText...
# 2                0    Summarize...  Example Title 1  Heading\nText...
# 3                0    Summarize...  Example Title 2  Heading\nText...
#
#    prompt_length  ...  wording_pred_3   wording  syl_complexity  \
# 0              3  ...       -1.385726 -1.402624               0
# 1              3  ...       -1.389704 -1.408819               0
# 2              3  ...       -1.390533 -1.409621               0
# 3              3  ...       -1.403584 -1.419664               0
#
#    lex_complexity  gramm_complexity  grammar_errors diffic_words  \
# 0        0.333333               0.0             1.0          1.0
# 1        0.333333               0.0             1.0          1.0
# 2        0.333333               0.0             1.0          1.0
# 3        0.333333               0.0             1.0          1.0
#
#    spelling_errors  self_bleu  self_novelty
# 0              0.0        -10           1.0
# 1              0.0        -10           1.0
# 2              0.0        -10           1.0
# 3              0.0        -10           1.0
#
# [4 rows x 35 columns]

# %%
targets = ["content", "wording"]

drop_columns = ["fold", "student_id", "prompt_id", "text", "fixed_summary_text",
                "prompt_question", "prompt_title", 
                "prompt_text"
               ] + targets

# %%
model_dict = {}

for target in targets:
    models = []
    
    for fold in range(CFG.n_splits):

        X_train_cv = train[train["fold"] != fold].drop(columns=drop_columns)
        y_train_cv = train[train["fold"] != fold][target]

        X_eval_cv = train[train["fold"] == fold].drop(columns=drop_columns)
        y_eval_cv = train[train["fold"] == fold][target]

        dtrain = lgb.Dataset(X_train_cv, label=y_train_cv)
        dval = lgb.Dataset(X_eval_cv, label=y_eval_cv)

        params = {
            'boosting_type': 'gbdt',
            'random_state': 42,
            'objective': 'regression',
            'metric': 'rmse',
            'learning_rate': 0.048, #0.048
            'max_depth': 5,  #5
            'lambda_l1': 0.0,
            'lambda_l2': 0.011 #0.011
        }

        evaluation_results = {}
        model = lgb.train(params,
                          num_boost_round=10000,
                            #categorical_feature = categorical_features,
                          valid_names=['train', 'valid'],
                          train_set=dtrain,
                          valid_sets=dval,
                          callbacks=[
                              lgb.early_stopping(stopping_rounds=30, verbose=True),
                               lgb.log_evaluation(100),
                              lgb.callback.record_evaluation(evaluation_results)
                            ],
                          )
        models.append(model)
    
    model_dict[target] = models
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000322 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3285
# [LightGBM] [Info] Number of data points in the train set: 5108, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score 0.017606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [45]	train's rmse: 0.413402
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3172
# [LightGBM] [Info] Number of data points in the train set: 5156, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.039959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.476346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [124]	train's rmse: 0.474646
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3201
# [LightGBM] [Info] Number of data points in the train set: 5169, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score 0.013356
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.428273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [75]	train's rmse: 0.423333
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3306
# [LightGBM] [Info] Number of data points in the train set: 6062, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.044904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.516404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [109]	train's rmse: 0.515449
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3285
# [LightGBM] [Info] Number of data points in the train set: 5108, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.031791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [54]	train's rmse: 0.523278
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000942 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3172
# [LightGBM] [Info] Number of data points in the train set: 5156, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.060941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [68]	train's rmse: 0.50881
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001228 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3306
# [LightGBM] [Info] Number of data points in the train set: 6062, number of used features: 19
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Start training from score -0.168933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 30 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	train's rmse: 0.636888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [86]	train's rmse: 0.636404

# %% [markdown]
# # CV Score

# %%
model_dict
# Out:
# {'content': [<lightgbm.basic.Booster at 0x7d6a7dc39f00>,
#   <lightgbm.basic.Booster at 0x7d6a7dc38a60>,
#   <lightgbm.basic.Booster at 0x7d6a7dc3a860>,
#   <lightgbm.basic.Booster at 0x7d6a7dc3a6e0>],
#  'wording': [<lightgbm.basic.Booster at 0x7d6a7dc39ae0>,
#   <lightgbm.basic.Booster at 0x7d6a7dc3a740>,
#   <lightgbm.basic.Booster at 0x7d6a7dc38430>,
#   <lightgbm.basic.Booster at 0x7d6a7dc38550>]}

# %%
train.head(3)
# Out:
#      student_id prompt_id                                               text  \
# 0  000e8c3c7ddb    814d6b  The third wave was an experimentto see how peo...
# 1  0020ae56ffbf    ebad26  They would rub it up with soda to make the sme...
# 2  004e978e639e    3b9047  In Egypt, there were many occupations and soci...
#
#     content   wording  summary_length  \
# 0  0.205683  0.380538              64
# 1 -0.548304  0.506755              54
# 2  3.128928  4.231226             269
#
#                                   fixed_summary_text  splling_err_num  \
# 0  The third wave was an experimental see how peo...                5
# 1  They would rub it up with soda to make the sme...                2
# 2  In Egypt, there were many occupations and soci...               32
#
#                                      prompt_question  \
# 0  Summarize how the Third Wave developed over su...
# 1  Summarize the various ways the factory would u...
# 2  In complete sentences, summarize the structure...
#
#                 prompt_title  ... content_pred  wording_pred  syl_complexity  \
# 0             The Third Wave  ...    -0.030020      0.686377           18.02
# 1    Excerpt from The Jungle  ...    -0.722237     -0.250455           61.00
# 2  Egyptian Social Structure  ...     2.439310      1.904997            0.00
#
#    lex_complexity  gramm_complexity  grammar_errors  diffic_words  \
# 0        0.281250          0.156250             4.0          11.0
# 1        0.145455          0.290909             4.0           3.0
# 2        0.152727          0.210909            13.0          38.0
#
#    spelling_errors  self_bleu  self_novelty
# 0              3.0   0.459545      0.803279
# 1              0.0   0.264532      0.673077
# 2              5.0   0.644615      0.587500
#
# [3 rows x 29 columns]

# %%
test.head(3)
# Out:
#      student_id prompt_id            text  summary_length fixed_summary_text  \
# 0  000000ffffff    abc123  Example text 1               3     Example text 1
# 1  111111eeeeee    def789  Example text 2               3     Example text 2
# 2  222222cccccc    abc123  Example text 3               3     Example text 3
#
#    splling_err_num prompt_question     prompt_title       prompt_text  \
# 0                0    Summarize...  Example Title 1  Heading\nText...
# 1                0    Summarize...  Example Title 2  Heading\nText...
# 2                0    Summarize...  Example Title 1  Heading\nText...
#
#    prompt_length  ...  wording_pred_3   wording  syl_complexity  \
# 0              3  ...       -1.385726 -1.402624               0
# 1              3  ...       -1.389704 -1.408819               0
# 2              3  ...       -1.390533 -1.409621               0
#
#    lex_complexity  gramm_complexity  grammar_errors diffic_words  \
# 0        0.333333               0.0             1.0          1.0
# 1        0.333333               0.0             1.0          1.0
# 2        0.333333               0.0             1.0          1.0
#
#    spelling_errors  self_bleu  self_novelty
# 0              0.0        -10           1.0
# 1              0.0        -10           1.0
# 2              0.0        -10           1.0
#
# [3 rows x 35 columns]

# %%
# cv
rmses = []

for target in targets:
    models = model_dict[target]

    preds = []
    trues = []
    
    for fold, model in enumerate(models):
        X_eval_cv = train[train["fold"] == fold].drop(columns=drop_columns)
        y_eval_cv = train[train["fold"] == fold][target]

        pred = model.predict(X_eval_cv)

        trues.extend(y_eval_cv)
        preds.extend(pred)
        
    rmse = np.sqrt(mean_squared_error(trues, preds))
    print(f"{target}_rmse : {rmse}")
    rmses = rmses + [rmse]

print(f"mcrmse : {sum(rmses) / len(rmses)}")
# Out:
# content_rmse : 0.45061900053973186
# wording_rmse : 0.5746319145023806
# mcrmse : 0.5126254575210563

# %%
"""
content_rmse : 0.44722283732964696
wording_rmse : 0.5685644558649501
mcrmse : 0.5078936465972985
"""
# Out:
# '\ncontent_rmse : 0.44722283732964696\nwording_rmse : 0.5685644558649501\nmcrmse : 0.5078936465972985\n'

# %% [markdown]
# # Predict

# %%
drop_columns = [
                #"fold", 
                "student_id", "prompt_id", "text", "fixed_summary_text",
                "prompt_question", "prompt_title", 
                "prompt_text",
                "input"
               ] + [
                f"content_pred_{i}" for i in range(CFG.n_splits)
                ] + [
                f"wording_pred_{i}" for i in range(CFG.n_splits)
                ]

# %%
pred_dict = {}
for target in targets:
    models = model_dict[target]
    preds = []

    for fold, model in enumerate(models):
        X_eval_cv = test.drop(columns=drop_columns)

        pred = model.predict(X_eval_cv)
        preds.append(pred)
    
    pred_dict[target] = preds

# %%
for target in targets:
    preds = pred_dict[target]
    for i, pred in enumerate(preds):
        test[f"{target}_pred_{i}"] = pred

    test[target] = test[[f"{target}_pred_{fold}" for fold in range(CFG.n_splits)]].mean(axis=1)

# %% [markdown]
# # Create a submission file

# %%
test
# Out:
#      student_id prompt_id            text  summary_length fixed_summary_text  \
# 0  000000ffffff    abc123  Example text 1               3     Example text 1
# 1  111111eeeeee    def789  Example text 2               3     Example text 2
# 2  222222cccccc    abc123  Example text 3               3     Example text 3
# 3  333333dddddd    def789  Example text 4               3     Example text 4
#
#    splling_err_num prompt_question     prompt_title       prompt_text  \
# 0                0    Summarize...  Example Title 1  Heading\nText...
# 1                0    Summarize...  Example Title 2  Heading\nText...
# 2                0    Summarize...  Example Title 1  Heading\nText...
# 3                0    Summarize...  Example Title 2  Heading\nText...
#
#    prompt_length  ...  wording_pred_3   wording  syl_complexity  \
# 0              3  ...        -1.30346 -1.274935               0
# 1              3  ...        -1.30346 -1.274935               0
# 2              3  ...        -1.30346 -1.274935               0
# 3              3  ...        -1.30346 -1.274935               0
#
#    lex_complexity  gramm_complexity  grammar_errors diffic_words  \
# 0        0.333333               0.0             1.0          1.0
# 1        0.333333               0.0             1.0          1.0
# 2        0.333333               0.0             1.0          1.0
# 3        0.333333               0.0             1.0          1.0
#
#    spelling_errors  self_bleu  self_novelty
# 0              0.0        -10           1.0
# 1              0.0        -10           1.0
# 2              0.0        -10           1.0
# 3              0.0        -10           1.0
#
# [4 rows x 35 columns]

# %%
sample_submission
# Out:
#      student_id   content   wording
# 0  000000ffffff -1.497897 -0.812235
# 1  111111eeeeee -1.497897 -0.812235
# 2  222222cccccc -1.497897 -0.812235
# 3  333333dddddd -1.497897 -0.812235

# %%
"""
for i in range(len(test)):
    test['wording'].iloc[i] = sample_submission['wording'].iloc[i]
"""
# Out:
# "\nfor i in range(len(test)):\n    test['wording'].iloc[i] = sample_submission['wording'].iloc[i]\n"

# %%
test
# Out:
#      student_id prompt_id            text  summary_length fixed_summary_text  \
# 0  000000ffffff    abc123  Example text 1               3     Example text 1
# 1  111111eeeeee    def789  Example text 2               3     Example text 2
# 2  222222cccccc    abc123  Example text 3               3     Example text 3
# 3  333333dddddd    def789  Example text 4               3     Example text 4
#
#    splling_err_num prompt_question     prompt_title       prompt_text  \
# 0                0    Summarize...  Example Title 1  Heading\nText...
# 1                0    Summarize...  Example Title 2  Heading\nText...
# 2                0    Summarize...  Example Title 1  Heading\nText...
# 3                0    Summarize...  Example Title 2  Heading\nText...
#
#    prompt_length  ...  wording_pred_3   wording  syl_complexity  \
# 0              3  ...        -1.30346 -1.274935               0
# 1              3  ...        -1.30346 -1.274935               0
# 2              3  ...        -1.30346 -1.274935               0
# 3              3  ...        -1.30346 -1.274935               0
#
#    lex_complexity  gramm_complexity  grammar_errors diffic_words  \
# 0        0.333333               0.0             1.0          1.0
# 1        0.333333               0.0             1.0          1.0
# 2        0.333333               0.0             1.0          1.0
# 3        0.333333               0.0             1.0          1.0
#
#    spelling_errors  self_bleu  self_novelty
# 0              0.0        -10           1.0
# 1              0.0        -10           1.0
# 2              0.0        -10           1.0
# 3              0.0        -10           1.0
#
# [4 rows x 35 columns]

# %%
test[["student_id", "content", "wording"]].to_csv("submission.csv", index=False) 
display(pd.read_csv('submission.csv'))
# Out:
#      student_id   content   wording
# 0  000000ffffff -1.418118 -1.274935
# 1  111111eeeeee -1.418118 -1.274935
# 2  222222cccccc -1.418118 -1.274935
# 3  333333dddddd -1.418118 -1.274935
